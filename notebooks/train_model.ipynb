# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\pieta\OneDrive\Bureau\tracéo_justin\Usual_analysis\data\data.xlsx')
df
# Out:
#           Site Artifact ID  Fracture ID Fracture composition  \
# 0    Maisières   P356.B1.3  P356.B1.3_1               simple
# 1    Maisières   P356.B1.3  P356.B1.3_2             multiple
# 2    Maisières   P356.B1.1  P356.B1.1_1               simple
# 3    Maisières   P356.B1.1  P356.B1.1_2             multiple
# 4    Maisières   P356.B1.1  P356.B1.1_3               simple
# ..         ...         ...          ...                  ...
# 218  Maisières   P357.B3.1  P357.B3.1_1               simple
# 219  Maisières   P357.B3.1  P357.B3.1_2               simple
# 220  Maisières   P358.B1.1  P358.B1.1_0                  NaN
# 221  Maisières   P358.B2.1  P358.B2.1_1               simple
# 222  Maisières   P358.B2.1  P358.B2.1_2               simple
#
#     Initiation morphology Location with respect to technological axis  \
# 0                 bending                                      Distal
# 1                  absent                                      Distal
# ...

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Site                                         223 non-null    object
#  1   Artifact ID                                  223 non-null    object
#  2   Fracture ID                                  223 non-null    object
#  3   Fracture composition                         204 non-null    object
#  4   Initiation morphology                        204 non-null    object
#  5   Location with respect to technological axis  204 non-null    object
#  6   Location of initiation                       204 non-null    object
#  7   Location of termination                      204 non-null    object
#  8   General direction                            204 non-null    object
# ...
