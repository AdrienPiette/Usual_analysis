# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\pieta\OneDrive\Bureau\tracéo_justin\Usual_analysis\data\Expdatatangedpoint05_07_22_testhadrien.xlsx')
df
# Out:
#        Tool ID          Type      Shoot ID Impacted material  \
# 0    Exp_78_43  tanged point  Exp_78_43_01   Bone; Gel; Skin
# 1     Exp78_31  tanged point   Exp78_31_01   Bone; Gel; Skin
# 2     Exp78_32  tanged point   Exp78_32_01   Bone; Gel; Skin
# 3     Exp78_32  tanged point   Exp78_32_01   Bone; Gel; Skin
# 4     Exp78_33  tanged point   Exp78_33_01   Bone; Gel; Skin
# ..         ...           ...           ...               ...
# 172   Exp78_98  tanged point   Exp78_98_01   Bone; Gel; Skin
# 173   Exp78_98  tanged point   Exp78_98_01   Bone; Gel; Skin
# 174   Exp78_98  tanged point   Exp78_98_01   Bone; Gel; Skin
# 175   Exp78_87  tanged point   Exp78_87_01   Bone; Gel; Skin
# 176   Exp78_87  tanged point   Exp78_87_01   Bone; Gel; Skin
#
#         State after shoot Mode of Propulsion  Penetration   Fracture ID  \
# 0    Point broken in haft      Spear thrower          9.5  Exp_78_43_01
# 1    Point broken in haft                Bow         16.5   Exp78_31_01
# 2    Point broken in haft           Throwing          8.0   Exp78_32_01
# 3    Point broken in haft           Throwing          8.0   Exp78_32_02
# 4    Point broken in haft      Spear thrower         18.0   Exp78_33_01
# ..                    ...                ...          ...           ...
# 172  Point broken in haft           Throwing         27.0   Exp78_98_03
# 173  Point broken in haft           Throwing         27.0   Exp78_98_04
# 174  Point broken in haft           Throwing         27.0   Exp78_98_05
# 175  Point broken in haft      Spear thrower          0.0   Exp78_87_01
# 176  Point broken in haft      Spear thrower          0.0   Exp78_87_02
#
#            Initation   Locus  ... Profile of initation  \
# 0            Bending  Distal  ...               convex
# 1    Absent; Bending  Distal  ...               convex
# 2               Cone  Distal  ...              Concave
# 3            Bending  Distal  ...               convex
# 4            Bending  Distal  ...               convex
# ..               ...     ...  ...                  ...
# 172             Cone  Mesial  ...              Concave
# 173          Bending  Mesial  ...               convex
# 174          Bending  Mesial  ...               convex
# 175          Bending  Mesial  ...             Straight
# 176  Absent; Bending  Mesial  ...          convex; N/A
#
#              General Direction Propagation Phase Lenght  \
# 0                 apex to base                     7.02
# 1    diagonal towards the base                     7.08
# 2    diagonal towards the base                     0.53
# 3    diagonal towards the base                     0.72
# 4    diagonal towards the base                     6.15
# ..                         ...                      ...
# 172  diagonal towards the base                      5,5
# 173  diagonal towards the base                      1,1
# 174  diagonal towards the base                      0,5
# 175               apex to base                       00
# 176               apex to base                      2,1
#
#                                            Termination  \
# 0                                Fissure; Step to step
# 1    Fissure; Hinge; Hinge to hinge; Hinge to step;...
# 2                                       Fissure; Hinge
# 3                                       Fissure; Hinge
# 4                              Fissure; Hinge to hinge
# ..                                                 ...
# 172                                      Fissure; Step
# 173                                      Fissure; Step
# 174                                      Fissure; Step
# 175                                                NaN
# 176  Fissure; Hinge; Hinge to hinge; Hinge to step;...
#
#     Location of termination fracture composition Fracture part Fracture group  \
# 0           Ventral surface               single      negative       fracture
# 1            Dorsal surface             multiple      negative        removal
# 2           Ventral surface               single      negative        removal
# 3           Ventral surface             multiple      negative        removal
# 4           Ventral surface             multiple      negative        removal
# ..                      ...                  ...           ...            ...
# 172         Ventral surface               single      negative        removal
# 173         Ventral surface               single      negative        removal
# 174         Ventral surface               single      negative        removal
# 175         Ventral surface               single      negative        removal
# 176         Ventral surface             multiple      negative        removal
#
#     enought traces for determination attribute group
# 0                                 no              BB
# 1                                yes              LS
# 2                             middel              LS
# 3                             middel              LS
# 4                                yes              LS
# ..                               ...             ...
# 172                              yes              LS
# 173                              yes              LS
# 174                              yes              LS
# 175                              yes              LS
# 176                              yes              SD
#
# [177 rows x 21 columns]

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Tool ID                           177 non-null    object
#  1   Type                              177 non-null    object
#  2   Shoot ID                          177 non-null    object
#  3   Impacted material                 177 non-null    object
#  4   State after shoot                 177 non-null    object
#  5   Mode of Propulsion                177 non-null    object
#  6   Penetration                       177 non-null    float64
#  7   Fracture ID                       177 non-null    object
#  8   Initation                         173 non-null    object
#  9   Locus                             176 non-null    object
#  10  Location of initiation            176 non-null    object
#  11  Profile of initation              160 non-null    object
#  12  General Direction                 175 non-null    object
#  13  Propagation Phase Lenght          174 non-null    object
#  14  Termination                       174 non-null    object
#  15  Location of termination           176 non-null    object
#  16  fracture composition              176 non-null    object
#  17  Fracture part                     175 non-null    object
#  18  Fracture group                    176 non-null    object
#  19  enought traces for determination  176 non-null    object
#  20  attribute group                   175 non-null    object
# dtypes: float64(1), object(20)
# memory usage: 29.2+ KB
# Index(['Tool ID', 'Type', 'Shoot ID', 'Impacted material', 'State after shoot',
#        'Mode of Propulsion', 'Penetration', 'Fracture ID', 'Initation',
#        'Locus', 'Location of initiation', 'Profile of initation',
#        'General Direction', 'Propagation Phase Lenght', 'Termination',
#        'Location of termination', 'fracture composition', 'Fracture part',
#        'Fracture group', 'enought traces for determination',
#        'attribute group'],
#       dtype='object')

# %%
df.drop(columns=['Tool ID', 'Shoot ID', 'Fracture ID', 'Type'], inplace=True)
df['Propagation Phase Lenght'] = pd.to_numeric(df['Propagation Phase Lenght'], errors='coerce')

# %%
object_cols = df.select_dtypes(include='object').columns
for col in object_cols:
    print(f"{col}: {df[col].nunique()} valeurs uniques")
    print(df[col].value_counts(), "\n")
# Out:
# Impacted material: 4 valeurs uniques
# Impacted material
# Bone; Gel; Skin    119
# Gel; Skin           45
# Gel                 10
# Skin                 3
# Name: count, dtype: int64
#
# State after shoot: 3 valeurs uniques
# State after shoot
# No dammage                   98
# Point broken in haft         77
# Point broken and dehafted     2
# Name: count, dtype: int64
#
# Mode of Propulsion: 4 valeurs uniques
# Mode of Propulsion
# Thrusting        57
# Spear thrower    52
# Throwing         46
# Bow              22
# Name: count, dtype: int64
#
# Initation: 10 valeurs uniques
# Initation
# Bending                          106
# Cone                              15
# Absent                            12
# Absent; Bending                   11
# Bending; Cone                     10
# Indetermined                       8
# Absent; Cone                       5
# Bending; Indetermined              3
# Absent; Bending; Cone              2
# Absent; Bending; Indetermined      1
# Name: count, dtype: int64
#
# Locus: 4 valeurs uniques
# Locus
# Distal            108
# Mesial             57
# Proximal            9
# Distal; Mesial      2
# Name: count, dtype: int64
#
# Location of initiation: 4 valeurs uniques
# Location of initiation
# Dorsal surface             138
# Ealier Fracture surface     18
# Ventral surface             18
# Right Lateral Edge           2
# Name: count, dtype: int64
#
# Profile of initation: 9 valeurs uniques
# Profile of initation
# convex                  102
# Concave                  31
# Straight                  9
# Concave; convex           8
# convex; N/A               5
# Concave; Straight         2
# Concave; convex; N/A      1
# convex; Straight          1
# Concave; N/A              1
# Name: count, dtype: int64
#
# General Direction: 7 valeurs uniques
# General Direction
# diagonal towards the base                                                               117
# apex to base                                                                             32
# base to apex                                                                             11
# diagonal towards the apex                                                                 7
# perpendicular to the long axis                                                            5
# diagonal towards the apex; diagonal towards the base                                      2
# diagonal towards the apex; diagonal towards the base; perpendicular to the long axis      1
# Name: count, dtype: int64
#
# Termination: 28 valeurs uniques
# Termination
# Fissure; Step                                                                       48
# Fissure; Hinge; Step                                                                24
# Hinge                                                                               19
# Fissure; Hinge                                                                      15
# Step                                                                                14
# Fissure; Step to step                                                               10
# Feather; Fissure; Step                                                               7
# Feather                                                                              6
# Feather; Fissure; Hinge; Step                                                        4
# Hinge to step                                                                        3
# Fissure; Hinge to hinge                                                              3
# Fissure; Hinge to step                                                               2
# Fissure                                                                              2
# Hinge; Step                                                                          2
# Feather; Fissure; Hinge                                                              2
# Hinge to step; Step to step                                                          1
# Feather; Hinge                                                                       1
# Fissure; Hinge; Snap; Step                                                           1
# Fissure; Step to hinge                                                               1
# Snap                                                                                 1
# Fissure; Step; Step to step                                                          1
# Fissure; Hinge; Step; Step to step                                                   1
# Fissure; Hinge; Step; Step to hinge                                                  1
# Fissure; Hinge; Hinge to hinge; Hinge to step; Step; Step to hinge; Step to step     1
# Absent                                                                               1
# Fissure; N/A                                                                         1
# Convex                                                                               1
# Fissure; Hinge; Hinge to hinge; Hinge to step; Step                                  1
# Name: count, dtype: int64
#
# Location of termination: 6 valeurs uniques
# Location of termination
# Ventral surface                       148
# Dorsal surface                         21
# Right Lateral Edge                      2
# Left lateral edge; Ventral surface      2
# Left lateral edge                       2
# Earlier fracture surface                1
# Name: count, dtype: int64
#
# fracture composition: 2 valeurs uniques
# fracture composition
# single      91
# multiple    85
# Name: count, dtype: int64
#
# Fracture part: 2 valeurs uniques
# Fracture part
# negative    173
# positive      2
# Name: count, dtype: int64
#
# Fracture group: 2 valeurs uniques
# Fracture group
# removal      150
#  fracture     26
# Name: count, dtype: int64
#
# enought traces for determination: 3 valeurs uniques
# enought traces for determination
# yes       141
# no         19
# middel     16
# Name: count, dtype: int64
#
# attribute group: 3 valeurs uniques
# attribute group
# LS    132
# BB     25
# SD     18
# Name: count, dtype: int64

# %%
cat_cols = ['Impacted material','State after shoot','Initation','Mode of Propulsion','Locus','Location of initiation','Profile of initation','General Direction',
            'Location of termination','Termination','fracture composition','Fracture part','Fracture group','enought traces for determination','attribute group']  # liste déterminée à la main
df[cat_cols] = df[cat_cols].astype('category')
